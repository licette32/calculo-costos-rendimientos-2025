# %% [markdown]
# # 📓 COSTOS

# %% [markdown]
# ### Funciones para los Cálculos
#
# Comenzaremos definiendo las funciones que se utilizarán en el cuaderno.

# %%
# En esta celda definimos las funciones que usaremos en todo el notebook.

def calcular_cantidad_necesaria(unidades_a_producir, consumo_neto_por_unidad, porcentaje_merma):
    """
    Calcula la cantidad total de materia prima requerida, ajustando por la merma.
    """
    if porcentaje_merma >= 1:
        raise ValueError("El porcentaje de merma debe ser un valor decimal (ej. 0.20 para 20%).")
    
    material_neto = unidades_a_producir * consumo_neto_por_unidad
    cantidad_total = material_neto / (1 - porcentaje_merma)
    return cantidad_total

def calcular_costo_compra(cantidad_total_material, costo_por_unidad_material):
    """
    Calcula el costo total de la compra de materia prima.
    """
    return cantidad_total_material * costo_por_unidad_material

# %% [markdown]
# #### Ejercicio 1: Producto "ZZ"
#
# Determinar la Cantidad necesaria de Materia Prima para una producción de 1.500 unidades del Producto “ZZ” teniendo en cuenta:
#
# - Consumo de Materia Prima por Unidad de Producto “ZZ”................. 1⁄2 litro
# - Precio de la Materia Prima por litro................................. $200
# - Merma de la Materia Prima ........................................... 20%

# %% [markdown]
# Para encontrar la cantidad total de material necesaria, primero se debe calcular la cantidad neta del material para la producción final. Luego, se ajusta esta cantidad para tener en cuenta el porcentaje de merma.
#
# La formula utilizada para este ajuste es:
#
# \begin{equation*}
# Cantidad\ Total = \frac{Cantidad\ Neta}{1 - Porcentaje\ de\ Merma}
# \end{equation*}
#
# EL costo total es la cantidad de material necesaria multiplicada por su costo por unidad.
#
# *Datos*:
#
# - **Producción:** 1.500 unidades
# - **Consumo:** 0,5 litro por unidad
# - **Merma:** 20%
# - **Precio:** $200 por litro

# %%
cantidad_zz = calcular_cantidad_necesaria(1500, 0.5, 0.20)
costo_zz = calcular_costo_compra(cantidad_zz, 200)

print(f"Cantidad necesaria: {cantidad_zz:.2f} litros")
print(f"Costo total de compra: ${costo_zz:,.2f}")
# Out:
# Cantidad necesaria: 937.50 litros
# Costo total de compra: $187,500.00

# %% [markdown]
# \begin{equation*}
# Cantidad\ Total\ (litros) = \frac{1500\ unidades \times 1,5\ \frac{litros}{unidad}}{1 - 0,20}
# \end{equation*}
#
# \begin{equation*}
# Costo\ Total\ (\$) = 937,50\ litros \times \$200\ \frac{\$}{litro}
# \end{equation*}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Ejercicio 2: Empresa Manufacturera
#
# En una empresa Manufacturera se procesa una sola materia prima. El desperdicio del Proceso 1 es del 20%. Si la producción del mes
# asciende a 1.500 unidades, y cada unidad requiere de 3 mts de materia prima.
#
# a) ¿Cuál es la cantidad inicial a incorporar de materia prima al proceso para la producción mensual?
#
# b) Si el sector de compras informa que el costo por metro de materia prima es de $320. ¿Cuál es el importe en pesos a comprar para la producción del mes?

# %% [markdown]
# El principio es el mismo, se determina la cantidad total de material necesaria ajustando por el desperdicio, y luego, se calcula el costo total basándose en el precio del material por metro.
#
# La fórmula para calcular la cantidad total de materia prima necesaria, considerando la merma, es la siguiente:
#
# \begin{equation*}
# Cantidad\ Total = \frac{Cantidad\ Neta}{1 - Porcentaje\ de\ Merma}
# \end{equation*}
#
#
# Una vez que se tiene la cantidad total de material, el costo de compra se calcula multiplicando esta cantidad por el precio por unidad del material:
#
# \begin{equation*}
# Costo\ Total = Cantidad\ Total \times Costo\ por\ metro
# \end{equation*}
#
#
# *Datos*:
#
# - **Producción:** 1.500 unidades
# - **Consumo:** 3 metros por unidad
# - **Desperdicio:** 20%
# - **Precio:** $320 por metro

# %%
cantidad_manuf = calcular_cantidad_necesaria(1500, 3, 0.20)
costo_manuf = calcular_costo_compra(cantidad_manuf, 320)

print(f"Cantidad necesaria: {cantidad_manuf:.2f} metros")
print(f"Costo total de compra: ${costo_manuf:,.2f}")
# Out:
# Cantidad necesaria: 5625.00 metros
# Costo total de compra: $1,800,000.00

# %% [markdown]
# \begin{equation*}
# Cantidad\ Total\ (mts) = \frac{1500\ unidades \times 3\ \frac{mts}{unidad}}{1 - 0,20}
# \end{equation*}
#
#
# \begin{equation*}
# Costo\ Total\ (\$) = 5625\ mts \times \$320\ \frac{\$}{mt}
# \end{equation*}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Ejercicio 3: Producto "Estrella"
#
# Determinar la cantidad necesaria de Materia prima para una producción de 4.500 unidades del producto “Estrella” teniendo en
# cuenta:
#
# ● Consumo de Materia Prima por Unidad de Producto “Estrella”: ........1,5 litro
#
# ● Precio de la Materia Prima por litro:........................................................ $60
#
# ● Merma de la Materia Prima: ........................................................ 20%

# %% [markdown]
# 🧮 *Datos*:
#
# - **Producción**: 4.500 unidades
#
# - **Consumo neto por unidad** : 1.5 litros
#
# - **Merma**: 20%
#
# - **Precio por litro**: $60

# %%
# Ejercicio 3: Producto "Estrella"
unidades_estrella = 4500
consumo_neto_estrella = 1.5  # litros
merma_estrella = 0.20
precio_litro_estrella = 60

# Calcula la cantidad necesaria de material.
cantidad_necesaria_estrella = calcular_cantidad_necesaria(unidades_estrella, consumo_neto_estrella, merma_estrella)

# Calcula el costo total de la compra.
costo_total_estrella = calcular_costo_compra(cantidad_necesaria_estrella, precio_litro_estrella)

print(f"La cantidad necesaria de materia prima es: {cantidad_necesaria_estrella:.2f} litros")
print(f"El costo total de la compra es: ${costo_total_estrella:.2f}")
# Out:
# La cantidad necesaria de materia prima es: 8437.50 litros
# El costo total de la compra es: $506250.00

# %% [markdown]
# #### Ejercicio 4: Producto "A"
#
# Determinar la Cantidad necesaria de Materia Prima para una producción de 2.000 unidades del Producto “A” teniendo en cuenta:
#
# ○ Consumo de Materia Prima por Unidad de Producto “A”..................500 grs.
#
# ○ Precio de la Materia Prima por kg...........................................................$10
#
# ○ Merma de la Materia Prima .....................................................................9%

# %% [markdown]
# Para calcular la cantidad necesaria y el costo de materia prima para una producción de 2000 unidades del Producto "A".
#
# Se debe convertir el consumo de gramos a kilogramos antes de realizar los cálculos, ya que el precio se da por kg.
#
# 🧮 *Datos*:
#
# - **Producción**: 2.000 unidades
#
# - **Consumo neto por unidad**: 500 gramos (0.5 kg)
#
# - **Merma**: 9% (0.09)
#
# - **Precio por kg**: $10
#
#
# \begin{equation*}
# Cantidad\ Neta\ (kg) = 2000\ unidades \times 500\ \frac{grs}{unidad} \times \frac{1\ kg}{1000\ grs}
# \end{equation*}
#
# \begin{equation*}
# Cantidad\ Total\ (kg) = \frac{Cantidad\ Neta\ (kg)}{1 - 0,09}
# \end{equation*}
#
# \begin{equation*}
# Costo\ Total\ (\$) = 1098,90\ kg \times \$10\ \frac{\$}{kg}
# \end{equation*}

# %%
# Ejercicio 4: Producto "A"
unidades_a = 2000
consumo_neto_a_grs = 500
consumo_neto_a_kg = consumo_neto_a_grs / 1000  # Convertir gramos a kilogramos
merma_a = 0.09
precio_kg_a = 10

# Calcula la cantidad necesaria de material en kg.
cantidad_necesaria_a = calcular_cantidad_necesaria(unidades_a, consumo_neto_a_kg, merma_a)

# Calcula el costo total de la compra.
costo_total_a = calcular_costo_compra(cantidad_necesaria_a, precio_kg_a)

print(f"La cantidad necesaria de materia prima es: {cantidad_necesaria_a:.2f} kg")
print(f"El costo total de la compra es: ${costo_total_a:.2f}")
# Out:
# La cantidad necesaria de materia prima es: 1098.90 kg
# El costo total de la compra es: $10989.01

# %% [markdown]
# #### Ejercicio 5: Producto "BB"
#
# Determinar la Cantidad necesaria de Materia Prima para una producción de 1.800 unidades del Producto “BB” teniendo en cuenta:
#
# ○ Consumo de Materia Prima por Unidad de Producto “BB”: .................1/4 litro
#
# ○ Precio de la Materia Prima por litro:.........................................................$180
#
# ○ Merma de la Materia Prima: ......................................................................15%

# %% [markdown]
# \begin{equation*}
# Cantidad\ Total\ (litros) = \frac{1800\ unidades \times 0,25\ \frac{litros}{unidad}}{1 - 0,15}
# \end{equation*}
#
# \begin{equation*}
# Costo\ Total\ (\$) = 529,41\ litros \times \$180\ \frac{\$}{litro}
# \end{equation*}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Ejercicio 6: Desperdicio de MP
#
# Trabajo con una empresa que posee un desperdicio de MP de un 15%, ¿Cuánto kg más tengo que comprar si sé que necesito 100 kg
# de MP para terminar el proceso productivo?

# %% [markdown]
# \begin{equation*}
# Cantidad\ Total\ (kg) = \frac{100\ kg\ (cantidad\ neta)}{1 - 0,15}
# \end{equation*}
#
# \begin{equation*}
# Cantidad\ Adicional\ (kg) = Cantidad\ Total\ (kg) - 100\ kg
# \end{equation*}

# %% [markdown]
# ![image.png](attachment:image.png)
